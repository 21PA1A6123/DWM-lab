# %% [markdown]
# <a href="https://colab.research.google.com/github/21PA1A6123/DWM-lab/blob/main/DWM_LAB_21_3_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/students_placement_data.csv')
df.head
# Out:
# <bound method NDFrame.head of      Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0          1      M       A            87.3                     65.30
# 1          2      F       A            89.0                     92.40
# 2          3      F       A            67.0                     68.00
# 3          4      M       A            71.0                     70.40
# 4          5      M       A             NaN                     65.50
# ..       ...    ...     ...             ...                       ...
# 112      113      M       B            81.1                     78.60
# 113      114      M       B            81.3                     85.12
# 114      115      M       B            83.5                     89.90
# 115      116      M       B            85.5                     90.63
# 116      117      M       B            80.0                     83.33
#
#      B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# ...

# %%
df.isnull().sum()
# Out:
# Roll No                               0
# Gender                                0
# Section                               0
# SSC Percentage                        1
# inter_Diploma_percentage              0
# B.Tech_percentage                     0
# Backlogs                              0
# registered_for_ Placement_Training    1
# placement status                      0
# dtype: int64

# %%
df['SSC Percentage']=df['SSC Percentage'].replace(to_replace=np.nan,value=np.mean(df['SSC Percentage']))
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A       87.300000                      65.3
# 1        2      F       A       89.000000                      92.4
# 2        3      F       A       67.000000                      68.0
# 3        4      M       A       71.000000                      70.4
# 4        5      M       A       80.474569                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              71.45         0                                yes
# 2              45.26        13                                yes
# 3              36.47        17                                yes
# 4              42.52        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
df.isna().any()
# Out:
# Roll No                               False
# Gender                                False
# Section                               False
# SSC Percentage                        False
# inter_Diploma_percentage              False
# B.Tech_percentage                     False
# Backlogs                              False
# registered_for_ Placement_Training     True
# placement status                      False
# dtype: bool

# %%
df['registered_for_ Placement_Training']=df['registered_for_ Placement_Training'].replace(to_replace=np.nan, value=df["registered_for_ Placement_Training"].mode()[0])
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A       87.300000                      65.3
# 1        2      F       A       89.000000                      92.4
# 2        3      F       A       67.000000                      68.0
# 3        4      M       A       71.000000                      70.4
# 4        5      M       A       80.474569                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              71.45         0                                yes
# 2              45.26        13                                yes
# 3              36.47        17                                yes
# 4              42.52        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
df.dtypes
# Out:
# Roll No                                 int64
# Gender                                 object
# Section                                object
# SSC Percentage                        float64
# inter_Diploma_percentage              float64
# B.Tech_percentage                     float64
# Backlogs                                int64
# registered_for_ Placement_Training     object
# placement status                       object
# dtype: object

# %%
print(df['Gender'].value_counts())
print(df['Section'].value_counts())
print(df['registered_for_ Placement_Training'].value_counts())
print(df['placement status'].value_counts())
# Out:
# M    68
# F    49
# Name: Gender, dtype: int64
# A    60
# B    57
# Name: Section, dtype: int64
# yes    68
# NO     49
# Name: registered_for_ Placement_Training, dtype: int64
# Not placed    78
# Placed        39
# Name: placement status, dtype: int64

# %%
import plotly.express as px
cut_counts = df['Gender'].value_counts()
fig = px.bar(x=cut_counts.index, y=cut_counts.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
cut_counts = df['Section'].value_counts()
fig = px.bar(x=cut_counts.index, y=cut_counts.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
cut_counts = df['registered_for_ Placement_Training'].value_counts()
fig = px.bar(x=cut_counts.index, y=cut_counts.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
cut_counts = df['placement status'].value_counts()
fig = px.bar(x=cut_counts.index, y=cut_counts.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pd.crosstab(index=df['Gender'], columns=df['placement status'])
# Out:
# placement status  Not placed  Placed
# Gender
# F                         20      29
# M                         58      10

# %%
pd.crosstab(index=df['Section'], columns=df['registered_for_ Placement_Training'])
# Out:
# registered_for_ Placement_Training  NO  yes
# Section
# A                                    5   55
# B                                   44   13

# %%
pd.crosstab(index=df['Section'], columns=df['placement status'])
# Out:
# placement status  Not placed  Placed
# Section
# A                         37      23
# B                         41      16

# %%
pd.pivot_table(df, values='B.Tech_percentage',
               index='Gender', columns='placement status', aggfunc=np.mean)
# Out:
# placement status  Not placed     Placed
# Gender
# F                  65.305500  75.264138
# M                  54.825345  69.574000

# %%
from sklearn.model_selection import train_test_split

X=df[["Gender","Section","SSC Percentage","inter_Diploma_percentage","B.Tech_percentage","Backlogs","registered_for_ Placement_Training"]].values
y=df["placement status"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=10)

# %%
X_train.shape

y_train.shape
# Out:
# (93,)
